# %% [markdown]
# <a href="https://colab.research.google.com/github/sammmy047/Project_Viveka/blob/main/Project_Viveka_module_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install libretranslatepy #this is used to import the translator api

# %%
pip install fpdf #this is used to create the required output pdf
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=b513f6aadd9ad81fa67f837496ad532aa8b91fe1af0bd033f710fcf899b7a27f
#   Stored in directory: /root/.cache/pip/wheels/f9/95/ba/f418094659025eb9611f17cbcaf2334236bf39a0c3453ea455
# Successfully built fpdf
# ...

# %%
pip install PyPDF2 #this is used to read the given input pdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.3 MB/s eta 0:00:00
# ...

# %%
pip install mosestokenizer
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mosestokenizer: filename=mosestokenizer-1.2.1-py3-none-any.whl size=49170 sha256=58c2c0b75afc4b8c5ec9c5f89bfced2e076437856639a768f6ecb9108dea9a72
#   Stored in directory: /root/.cache/pip/wheels/80/d8/15/4c5ebbe883513f003cb055a0369c77c9df857023a706f39e70
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=2ba0685e567ca18b052cf0a458d25bd5645db261a3140f72f9314e2dc55c30fd
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# ...
#   Created wheel for toolwrapper: filename=toolwrapper-2.1.0-py3-none-any.whl size=3337 sha256=d94315b9f201dd90d4b65218d2c06418c7eebc65a128c6a0cd15326840b28384
#   Stored in directory: /root/.cache/pip/wheels/e1/af/b1/99b57a06dda78fdcee86d2e22c64743f3b8df8f31cfc04baf7
# ...

# %%
pip install python-docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 50.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184487 sha256=88c9cfee72303db5a4731a4ff1a457de5866967f3ec51ca97ce2e542d2957743
#   Stored in directory: /root/.cache/pip/wheels/80/27/06/837436d4c3bd989b957a91679966f207bfd71d358d63a8194d
# Successfully built python-docx
# ...

# %%
# !apt-get install -qq -y libreoffice
# !apt-get install -qq -y unoconv
# Out:
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-opensymbol.
# (Reading database ... 120895 files and directories currently installed.)
# Preparing to unpack .../000-fonts-opensymbol_2%3a102.12+LibO7.3.7-0ubuntu0.22.04.3_all.deb ...
# Unpacking fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../001-libreoffice-style-colibre_1%3a7.3.7-0ubuntu0.22.04.3_all.deb ...
# Unpacking libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../002-libuno-sal3_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libuno-sal3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../003-libuno-salhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# ...

# %%
#Creating Input pdf file if not created and converting input text to pdf.
from mosestokenizer import *
from fpdf import FPDF

lang = input("enter language:\n") # This is the language of the input file
input_txt = input("enter text\n") # We take the text input from the user
# The function given below splits the sentences
text = input_txt.split('\n')
pdf = FPDF()
pdf.add_page() # Adding a page to a newly created pdf file
# set style and size of font
pdf.add_font("modified",fname='ArialUnicodeRegular.ttf',uni=True)
pdf.set_font("modified", size = 11)
f = text
# insert the texts in pdf
for x in f:
    pdf.multi_cell(200, 10, txt = x, align = 'L')

# save the pdf with name input.pdf
pdf.output("input1.pdf")
print("PDF File Generated")
# Out:
# enter language:
# en
# enter text
# ...

# %%
#taking input as pdf and translating to given language and providing output pdf for it.
from libretranslatepy import LibreTranslateAPI
from fpdf import FPDF
from mosestokenizer import *
lt = LibreTranslateAPI("https://translate.argosopentech.com/") #this line contains the url from which we are implementing the language translation.
import PyPDF2
from fpdf import FPDF
import docx
import subprocess
import os
from docx.shared import Pt
# create a pdf file object
inputpdf = input("Enter name of input pdf :")
pdfFileObj = open(inputpdf.strip()+".pdf", 'rb') # Here we are opening an aldready existing pdf that has been uplaoded on google colaboratory.
# create a pdf reader object
pdfReader = PyPDF2.PdfReader(pdfFileObj)
print("Language Options Are Given Below \n")
print(lt.languages()) # Lists upto 17 languages
print()
en_paragraphs=[]
text_file_path = "/content/input.pdf"
inlang = input("Enter the input language of pdf file \n")
outlang = input("Enter the language to translate to \n ").strip()

extracted_text=''
pdf_reader = PyPDF2.PdfReader(text_file_path)
for pageObj in pdfReader.pages:
        extracted_text += pageObj.extract_text()

pdfFileObj.close()
# The below function is used to split the extracted text into sentences for faster translation.
def split_sentences(paragraph, language):
    if language == inlang:
        with MosesSentenceSplitter(language) as splitter:
            return splitter([paragraph])

text = split_sentences(extracted_text,inlang)
#text = extracted_text.split('\n')  # We store the split sentences into variable text.
translated_text=lt.translate(text, inlang, outlang) # Here we are translating the given input text from input  language into the rquired output language.
pdf = FPDF()
# we create a .txt file to store the translated text into it.
file = open("translated"+outlang+".txt", "w")
file.write(translated_text)
file.close()
def pdf(outlang):
    pdf = FPDF(orientation = 'P', unit = 'mm', format='A4')
# Add a page
    pdf.add_page()
# set style and size of font
    pdf.add_font("modified",fname='Arial-Unicode-Regular.ttf',uni=True)
    pdf.set_font("modified", size = 15)
#pdf.set_doc_option(opt:'windows-1252',file)
# open the text file in read mode
    file = open("translated"+outlang+".txt", "r")
    f = file
# insert the texts in pdf
    for x in f:
      pdf.multi_cell(200, 10, txt = x, align = 'L')
# save the pdf with name .pdf
    pdf.output("translated"+outlang+".pdf")
    print("PDF Translation Successful")
def doc(outlang):
  doc = docx.Document()
  paragraphs = translated_text.split('\n\n')

    # Add each paragraph as a separate paragraph in the document
  for paragraph in paragraphs:
      paragraph = paragraph.strip()  # Remove leading and trailing whitespace
      if paragraph:  # Skip empty paragraphs
            doc.add_paragraph(paragraph)
# Creating paragraph with some content
# Now save the document to a location
  doc.save("translated"+outlang+'.docx')
# using docx2pdf module
  subprocess.run(["unoconv", "-f", "pdf", "-o", '/content/translated'+outlang+".pdf",'/content/translated'+outlang+".docx" ])
  print("Translation to PDF Successful")
for i in range(1):
 if outlang == 'zh':
    pdf(outlang)
    break
 if outlang == 'ko':
    pdf(outlang)
    break
 else:
    doc(outlang)
# Out:
# Enter name of input pdf :input
# Language Options Are Given Below
#
# [{'code': 'en', 'name': 'English'}, {'code': 'ar', 'name': 'Arabic'}, {'code': 'zh', 'name': 'Chinese'}, {'code': 'fr', 'name': 'French'}, {'code': 'de', 'name': 'German'}, {'code': 'hi', 'name': 'Hindi'}, {'code': 'id', 'name': 'Indonesian'}, {'code': 'ga', 'name': 'Irish'}, {'code': 'it', 'name': 'Italian'}, {'code': 'ja', 'name': 'Japanese'}, {'code': 'ko', 'name': 'Korean'}, {'code': 'pl', 'name': 'Polish'}, {'code': 'pt', 'name': 'Portuguese'}, {'code': 'ru', 'name': 'Russian'}, {'code': 'es', 'name': 'Spanish'}, {'code': 'tr', 'name': 'Turkish'}, {'code': 'vi', 'name': 'Vietnamese'}]
#
# Enter the input language of pdf file
# en
# Enter the language to translate to
#  fr
# Translation to PDF Successful
